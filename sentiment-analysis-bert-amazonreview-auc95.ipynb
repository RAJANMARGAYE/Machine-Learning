# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Model
import os
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Verbosity is now 5

tf.autograph.set_verbosity(0)

# %%
# !nvidia-smi
# Out:
# Fri Sep 17 14:23:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Read data

# %%
data=pd.read_csv('../input/amazon-fine-food-reviews/Reviews.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %% [markdown]
# ### There are no null values

# %% [markdown]
# ### Unique labels

# %%
np.unique(data.Score,return_counts=True)
# Out:
# (array([1, 2, 3, 4, 5]), array([ 52268,  29769,  42640,  80655, 363122]))

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data.shape
# Out:
# (568454, 10)

# %% [markdown]
# ### We are doing sentiment analysis hence we will convert label to 0 or 1
# ### 0: Negative Review
# ### 1: Positive Review

# %%
data.loc[data['Score'] <=2, 'Score'] = 0
data.loc[data['Score'] > 3, 'Score'] = 1

# %% [markdown]
# ### Dropping Score=3 as it is neutral value

# %%
data.drop(data[data['Score']==3].index,inplace=True)

# %%
data['len'] = data.Text.apply(lambda x: len(x.split()))

# %% [markdown]
# ### We are considering first 50 words only

# %%
data = data[data.len<50]

# %% [markdown]
# If you want to take fix data, then use below line

# %%
data = data.sample(n=50000, random_state=30)

# %%
import re

# %% [markdown]
# ### Removing html tags

# %%
data['Text']=data['Text'].apply(lambda row : re.sub('<.*?>','',row))

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting of data

# %%
X_train, X_test, y_train, y_test = train_test_split(data[['Text','len']],data.Score, test_size=0.2, random_state=42, stratify=data.Score)

# %%
X_train.shape,X_test.shape
# Out:
# ((40000, 2), (10000, 2))

# %% [markdown]
# we are importing bert layer from tensorflow hub and creating a model with pooled output only so it will take less time to train

# %%
max_seq_length = 55
tf.keras.backend.clear_session()
input_word_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_word_ids")
                # ids of words
input_mask = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_mask")
                # masking of ids
segment_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="segment_ids")
                # segment of ids
bert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1", trainable=False)
pooled_output, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])

bert_model = Model(inputs=[input_word_ids, input_mask, segment_ids], outputs=pooled_output)
# Out:
# 2021-09-17 14:24:01.922189: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-17 14:24:01.925466: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-17 14:24:01.974608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:01.975215: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-17 14:24:01.975267: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 14:24:02.000596: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 14:24:02.000686: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-17 14:24:02.016824: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-17 14:24:02.040776: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-17 14:24:02.070543: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-17 14:24:02.086643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-17 14:24:02.088952: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-17 14:24:02.089109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:02.089844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:02.091301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-17 14:24:02.091812: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-17 14:24:02.092005: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-17 14:24:02.092159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:02.092742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-17 14:24:02.092778: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 14:24:02.092803: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 14:24:02.092820: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-17 14:24:02.092837: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-17 14:24:02.092853: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-17 14:24:02.092869: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-17 14:24:02.092887: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-17 14:24:02.092903: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-17 14:24:02.092988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:02.093597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:02.094120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-17 14:24:02.095266: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-17 14:24:03.516284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-17 14:24:03.516333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-17 14:24:03.516343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-17 14:24:03.517704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:03.518431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:03.519082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-17 14:24:03.519647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)

# %%
bert_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_word_ids (InputLayer)     [(None, 55)]         0
# __________________________________________________________________________________________________
# input_mask (InputLayer)         [(None, 55)]         0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 55)]         0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        [(None, 768), (None, 109482241   input_word_ids[0][0]
#                                                                  input_mask[0][0]
#                                                                  segment_ids[0][0]
# ==================================================================================================
# Total params: 109,482,241
# Trainable params: 0
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()

# %%
# !wget --quiet https://raw.githubusercontent.com/tensorflow/models/master/official/nlp/bert/tokenization.py

# %%
import tokenization

# %%
def bert_preprocess(sentence,tokenizer,max_seq_len=512):
    tokens=[]
    masks=[]
    segments=[]
    for word in sentence:
        word=tokenizer.tokenize(word)
        word=word[:max_seq_len-2]
        seq=["[CLS]"] + word + ["[SEP]"]
        token = tokenizer.convert_tokens_to_ids(seq)
        padding_tokens=token+[0]*(max_seq_len-len(token))
        mask=[1]*len(seq)
        masking=mask+[0]*(max_seq_len-len(token))
        segment=np.zeros(max_seq_length)
        
        tokens.append(padding_tokens)
        masks.append(masking)
        segments.append(segment)
    return np.array(tokens),np.array(masks),np.array(segments)

# %%
tokenizer =tokenization.FullTokenizer(vocab_file,do_lower_case)

# %%
bert_model.input
# Out:
# [<KerasTensor: shape=(None, 55) dtype=int32 (created by layer 'input_word_ids')>,
#  <KerasTensor: shape=(None, 55) dtype=int32 (created by layer 'input_mask')>,
#  <KerasTensor: shape=(None, 55) dtype=int32 (created by layer 'segment_ids')>]

# %%
bert_model.output
# Out:
# <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'keras_layer')>

# %%
X_train_tokens, X_train_mask, X_train_segment=bert_preprocess(X_train.Text.values,tokenizer,55)
X_test_tokens, X_test_mask, X_test_segment=bert_preprocess(X_test.Text.values,tokenizer,55)

# %%
X_train_pooled_output=bert_model.predict([X_train_tokens,X_train_mask,X_train_segment])
X_test_pooled_output=bert_model.predict([X_test_tokens,X_test_mask,X_test_segment])
# Out:
# 2021-09-17 14:24:48.939956: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-17 14:24:48.949605: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000140000 Hz
# 2021-09-17 14:24:50.512014: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-17 14:24:51.263716: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11

# %%
from tensorflow.keras.layers import Input, Dense, Activation, Dropout
from tensorflow.keras.models import Model

# %%
import datetime
from sklearn.metrics import roc_auc_score

# %%
auc=[]
val_auc=[]
class LossHistory(tf.keras.callbacks.Callback):
    
    def on_train_begin(self, logs={}):
        self.history={'val_accuracy': []}


    def on_epoch_end(self, epoch, logs={}):
        ## on end of each epoch, we will get logs and update the self.history dict
        if logs.get('val_accuracy', -1) != -1:
            self.history['val_accuracy'].append(logs.get('val_accuracy'))
        auc_tr=(roc_auc_score(y_train,(self.model.predict(X_train_pooled_output))) )
        auc_test=(roc_auc_score (y_test, (self.model.predict(X_test_pooled_output) ) ) )
        print('\n  train_auc : ',auc_tr)
        print('  val_auc : ',auc_test)
        auc.append(auc_tr)
        val_auc.append(auc_test)
        loss=logs.get('loss')

# %%
#Callbacks
filepath="model1_save/weights-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, monitor='val_loss',  verbose=1, save_best_only=True, mode='auto')

history_own = LossHistory()

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',mode='max', patience=2, verbose=1)

# %%
##create an NN and 
input = Input(shape=[768,],name='input_layer')
dense1=Dense(400, activation='relu',name='dense_1')(input)
dense2=Dense(220, activation='relu',name='dense_2')(dense1)
dense3=Dense(40, activation='relu',name='dense_3')(dense2)
output=Dense(1, activation='sigmoid',name='dense_4')(dense3)
model1 = Model(inputs=input, outputs=output)
tf.keras.utils.plot_model(model1,"model_1.png",show_shapes=True)

# %%
opt= tf.keras.optimizers.Adam(learning_rate=0.001)
model1.compile(optimizer=opt,loss=tf.keras.losses.BinaryCrossentropy(),metrics='accuracy')

# %%
X_test_pooled_output.shape
# Out:
# (10000, 768)

# %%
# !rm -rf ./logs_model1/ 
tf.keras.backend.clear_session()
model1.fit(X_train_pooled_output,y_train,validation_data=(X_test_pooled_output,y_test),epochs=50,callbacks=[history_own])
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.3205 - accuracy: 0.8771 - val_loss: 0.2294 - val_accuracy: 0.9044
#
#   train_auc :  0.9396089052573066
#   val_auc :  0.9305311769223916
# Epoch 2/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2210 - accuracy: 0.9105 - val_loss: 0.2024 - val_accuracy: 0.9195
#
#   train_auc :  0.9461040805497106
#   val_auc :  0.9378756778089049
# Epoch 3/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2099 - accuracy: 0.9128 - val_loss: 0.1998 - val_accuracy: 0.9196
#
#   train_auc :  0.9485713189026594
#   val_auc :  0.9404804128137916
# Epoch 4/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.2107 - accuracy: 0.9132 - val_loss: 0.2250 - val_accuracy: 0.9114
#
#   train_auc :  0.9493171597350127
#   val_auc :  0.9408566291214251
# Epoch 5/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1951 - accuracy: 0.9204 - val_loss: 0.2207 - val_accuracy: 0.9107
#
#   train_auc :  0.9505463438940865
#   val_auc :  0.9430420679203895
# Epoch 6/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1893 - accuracy: 0.9222 - val_loss: 0.2258 - val_accuracy: 0.9001
#
#   train_auc :  0.9527346356158332
#   val_auc :  0.9449974511800383
# Epoch 7/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1904 - accuracy: 0.9227 - val_loss: 0.1877 - val_accuracy: 0.9248
#
#   train_auc :  0.9539829868235036
#   val_auc :  0.9470476990404552
# Epoch 8/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1878 - accuracy: 0.9249 - val_loss: 0.1815 - val_accuracy: 0.9303
#
#   train_auc :  0.954543228771179
#   val_auc :  0.9469778385456012
# Epoch 9/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1951 - accuracy: 0.9210 - val_loss: 0.1818 - val_accuracy: 0.9275
#
#   train_auc :  0.9546884280482127
#   val_auc :  0.947937143497187
# Epoch 10/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1836 - accuracy: 0.9260 - val_loss: 0.1864 - val_accuracy: 0.9250
#
#   train_auc :  0.9551696503400077
#   val_auc :  0.947920488897333
# Epoch 11/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1855 - accuracy: 0.9250 - val_loss: 0.1968 - val_accuracy: 0.9219
#
#   train_auc :  0.9557494119166928
#   val_auc :  0.9488477281926668
# Epoch 12/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1871 - accuracy: 0.9251 - val_loss: 0.1811 - val_accuracy: 0.9302
#
#   train_auc :  0.9564440453024408
#   val_auc :  0.9495722699047117
# Epoch 13/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1823 - accuracy: 0.9262 - val_loss: 0.2088 - val_accuracy: 0.9129
#
#   train_auc :  0.9565399027552128
#   val_auc :  0.949816093246573
# Epoch 14/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.1870 - accuracy: 0.9244 - val_loss: 0.1846 - val_accuracy: 0.9283
#
#   train_auc :  0.9574663702555523
#   val_auc :  0.950099887628084
# Epoch 15/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1829 - accuracy: 0.9235 - val_loss: 0.1785 - val_accuracy: 0.9289
#
#   train_auc :  0.9577336428659914
#   val_auc :  0.95122369561396
# Epoch 16/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1744 - accuracy: 0.9278 - val_loss: 0.1766 - val_accuracy: 0.9315
#
#   train_auc :  0.9579030813523669
#   val_auc :  0.9506146702065019
# Epoch 17/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1805 - accuracy: 0.9247 - val_loss: 0.1852 - val_accuracy: 0.9277
#
#   train_auc :  0.9580159820425853
#   val_auc :  0.950898997535208
# Epoch 18/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1813 - accuracy: 0.9256 - val_loss: 0.1966 - val_accuracy: 0.9282
#
#   train_auc :  0.9573378061110781
#   val_auc :  0.9493611339908304
# Epoch 19/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1736 - accuracy: 0.9300 - val_loss: 0.1990 - val_accuracy: 0.9157
#
#   train_auc :  0.9581798819626296
#   val_auc :  0.9508308247064726
# Epoch 20/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1761 - accuracy: 0.9276 - val_loss: 0.1747 - val_accuracy: 0.9307
#
#   train_auc :  0.9592703160123829
#   val_auc :  0.9520969740057672
# Epoch 21/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.1795 - accuracy: 0.9246 - val_loss: 0.1771 - val_accuracy: 0.9303
#
#   train_auc :  0.9588504565935784
#   val_auc :  0.9513782503006044
# Epoch 22/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1714 - accuracy: 0.9312 - val_loss: 0.1817 - val_accuracy: 0.9278
#
#   train_auc :  0.9594670919737768
#   val_auc :  0.9527599603167519
# Epoch 23/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1733 - accuracy: 0.9295 - val_loss: 0.1743 - val_accuracy: 0.9321
#
#   train_auc :  0.9601363340173377
#   val_auc :  0.9530711570665557
# Epoch 24/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1774 - accuracy: 0.9293 - val_loss: 0.1781 - val_accuracy: 0.9304
#
#   train_auc :  0.9599006215182025
#   val_auc :  0.9526748220022987
# Epoch 25/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1711 - accuracy: 0.9310 - val_loss: 0.1737 - val_accuracy: 0.9318
#
#   train_auc :  0.960490477444351
#   val_auc :  0.953530557548926
# Epoch 26/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1736 - accuracy: 0.9291 - val_loss: 0.1804 - val_accuracy: 0.9311
#
#   train_auc :  0.9602611336024408
#   val_auc :  0.953032118684498
# Epoch 27/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1749 - accuracy: 0.9290 - val_loss: 0.1797 - val_accuracy: 0.9307
#
#   train_auc :  0.95962502856526
#   val_auc :  0.9526301876746901
# Epoch 28/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1690 - accuracy: 0.9332 - val_loss: 0.1763 - val_accuracy: 0.9302
#
#   train_auc :  0.9607776777886871
#   val_auc :  0.9534610079399363
# Epoch 29/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.1724 - accuracy: 0.9308 - val_loss: 0.1707 - val_accuracy: 0.9325
#
#   train_auc :  0.9610318799378298
#   val_auc :  0.9537458682158376
# Epoch 30/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1629 - accuracy: 0.9328 - val_loss: 0.1710 - val_accuracy: 0.9325
#
#   train_auc :  0.9611863878930126
#   val_auc :  0.9540635491565178
# Epoch 31/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1720 - accuracy: 0.9293 - val_loss: 0.2149 - val_accuracy: 0.9166
#
#   train_auc :  0.9598820235954696
#   val_auc :  0.9533349659282416
# Epoch 32/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1742 - accuracy: 0.9288 - val_loss: 0.1931 - val_accuracy: 0.9221
#
#   train_auc :  0.9615390155018726
#   val_auc :  0.9547106802884419
# Epoch 33/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1753 - accuracy: 0.9290 - val_loss: 0.1883 - val_accuracy: 0.9289
#
#   train_auc :  0.9612369651368321
#   val_auc :  0.9542803254282163
# Epoch 34/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1685 - accuracy: 0.9326 - val_loss: 0.1743 - val_accuracy: 0.9311
#
#   train_auc :  0.9608478496195566
#   val_auc :  0.9545768217178824
# Epoch 35/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1719 - accuracy: 0.9291 - val_loss: 0.1843 - val_accuracy: 0.9226
#
#   train_auc :  0.9614257594550171
#   val_auc :  0.9552784911127947
# Epoch 36/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1640 - accuracy: 0.9335 - val_loss: 0.2552 - val_accuracy: 0.8842
#
#   train_auc :  0.9595946150343542
#   val_auc :  0.9514656536406378
# Epoch 37/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1627 - accuracy: 0.9330 - val_loss: 0.1706 - val_accuracy: 0.9327
#
#   train_auc :  0.962353515123165
#   val_auc :  0.9556440484765215
# Epoch 38/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1668 - accuracy: 0.9333 - val_loss: 0.1777 - val_accuracy: 0.9254
#
#   train_auc :  0.9620087997519211
#   val_auc :  0.9550616260165635
# Epoch 39/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1666 - accuracy: 0.9335 - val_loss: 0.1806 - val_accuracy: 0.9241
#
#   train_auc :  0.9622913804599791
#   val_auc :  0.9554085746407202
# Epoch 40/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1672 - accuracy: 0.9303 - val_loss: 0.1976 - val_accuracy: 0.9156
#
#   train_auc :  0.9621843015109113
#   val_auc :  0.9554962444543514
# Epoch 41/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1644 - accuracy: 0.9324 - val_loss: 0.1682 - val_accuracy: 0.9326
#
#   train_auc :  0.9628233937648203
#   val_auc :  0.9559372582584832
# Epoch 42/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1646 - accuracy: 0.9328 - val_loss: 0.1746 - val_accuracy: 0.9310
#
#   train_auc :  0.9627100488788057
#   val_auc :  0.9555516709626651
# Epoch 43/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1654 - accuracy: 0.9336 - val_loss: 0.1681 - val_accuracy: 0.9315
#
#   train_auc :  0.9628478994916394
#   val_auc :  0.9557222140651693
# Epoch 44/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1658 - accuracy: 0.9336 - val_loss: 0.1788 - val_accuracy: 0.9266
#
#   train_auc :  0.9627500570389045
#   val_auc :  0.9555609975385835
# Epoch 45/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1639 - accuracy: 0.9338 - val_loss: 0.1869 - val_accuracy: 0.9264
#
#   train_auc :  0.9626687830893593
#   val_auc :  0.9560374523312042
# Epoch 46/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1681 - accuracy: 0.9314 - val_loss: 0.1740 - val_accuracy: 0.9294
#
#   train_auc :  0.9633477613495232
#   val_auc :  0.9566625549790548
# Epoch 47/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1669 - accuracy: 0.9324 - val_loss: 0.1724 - val_accuracy: 0.9316
#
#   train_auc :  0.9628954256655854
#   val_auc :  0.9553294763944806
# Epoch 48/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1601 - accuracy: 0.9355 - val_loss: 0.1715 - val_accuracy: 0.9325
#
#   train_auc :  0.9632192860442081
#   val_auc :  0.9564654533413167
# Epoch 49/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1669 - accuracy: 0.9308 - val_loss: 0.1670 - val_accuracy: 0.9335
#
#   train_auc :  0.9638682283398928
#   val_auc :  0.9566338646550399
# Epoch 50/50
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.1686 - accuracy: 0.9305 - val_loss: 0.1681 - val_accuracy: 0.9333
#
#   train_auc :  0.9639090027377397
#   val_auc :  0.9563274200177276

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(12,10))
plt.plot(np.arange(len(auc)),auc,color="red")
plt.plot(np.arange(len(auc)),val_auc,color='blue')
plt.scatter(np.arange(len(auc)),auc,color='red')
plt.scatter(np.arange(len(auc)),val_auc,color='blue')
plt.xticks(np.arange(0,len(auc)+1,5),rotation=-35)
plt.xlabel('Epochs')
plt.ylabel('AUC Score')
plt.legend(['Train AUC','Test AUC'])
plt.grid()
plt.show()

# %% [markdown]
# # We have achieved 95%+ AUC without overfitting model
